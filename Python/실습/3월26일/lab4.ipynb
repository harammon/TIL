# %%
import requests
from bs4 import BeautifulSoup
import re

title=[]
summary=[]
rating=[]
for n in range(1,11):
    req = requests.get('https://comic.naver.com/genre/bestChallenge.nhn?page='+str(n)) # 문자열로 줘야하기 때문에!! 
    html = req.text
    r = requests.get(url)
    r.encoding = 'utf-8'
    bs = BeautifulSoup(r.text, 'html.parser')
    titleList = bs.select('.challengeTitle')
    summaryList = bs.select('.summary')
    ratingList = bs.select('.rating_type > strong')
    for titleDom in titleList:
        title.append(titleDom.text.strip())
    for summaryDom in summaryList:
        summary.append(summaryDom.text.strip())
    for ratingDom in ratingList:
        rating.append(ratingDom.text.strip())

print("================================title================================")        
print(title, '\n')
print("================================summary===============================")
print(summary, '\n')
print("================================rating================================")
print(rating, '\n')
# Out:
# ================================title================================
# ...

# %%
# Out:
# 주짓수와 고양이
# 식봉툰
# 방에 콕! 진댕
# 전지적덕후시점
# 만화 임진왜란
# 결혼하고 싶지 않았는데 못하게 되었다.
# 케어시트
# 사자머리와호깜대
# 일요극장
# 뭉가툰
# 모노톤 책꽂이
# 이상한사무실
# 눈치없는 내 친구!
# 아빠는 N살
# 애포칼립스
# 오늘도 그래고래
# 무엇이든 그려드립니닷!
# 느린한끼
# 전송
# 내 매력에 퐁당
# 저승파견고용직
# 엑스마키나
# 런어웨이
# 김작가의 오춘기 그림일기

# %%
for newscomnameDom in newscomnameList:
    newscomname.append(newscomnameDom.string)
    print(newscomnameDom.string)
